# %%
import torch
import torch.nn as nn
from torch.functional import F
from torch.optim.lr_scheduler import StepLR, LambdaLR, CyclicLR
from torch.utils.data import Dataset, TensorDataset, DataLoader

from pytorchtools import EarlyStopping

import pandas as pd
import numpy as np
import cv2
import os

from matplotlib import pyplot as plt
from sklearn.metrics import f1_score

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size(0), -1)
    
def Network():
    network = nn.Sequential(
        nn.Conv2d(1, 16, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.Conv2d(16, 16, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        
        nn.Dropout(0.3), ##
        
        nn.Conv2d(16, 16, 4, stride=2, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        
        nn.Dropout(0.3),
        
        
        
        nn.Conv2d(16, 32, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        
        nn.Conv2d(32, 32, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        
        nn.Dropout(0.3), ##
        
        nn.Conv2d(32, 32, 4, stride=2, padding=1),
        nn.ReLU(),
        
        nn.Dropout(0.3),
        
        
        
        
        nn.Conv2d(32, 64, 4, stride=1, padding=1),
        nn.ReLU(),
        nn.Dropout(0.3),
        
        Flatten(),
        nn.Linear(64*6*6,100),
        nn.ReLU(),
        nn.Linear(100, 10)
    )
    return network

# %%
def data_train(path, filenames):
    my_x = []
    my_y_np = np.array([])
    
    for filename in filenames:
        my_x.append(cv2.imread(os.path.join(path, filename), 0))
        pre, ext = os.path.splitext(os.path.join(path, filename))
        my_y_np = np.append(my_y_np, np.array(ext[1:]).astype(np.uint8))
        
    my_y = torch.from_numpy(my_y_np).float()
    
    tensor_x = torch.Tensor(my_x)
    tensor_x = tensor_x.unsqueeze(1)
    tensor_y = torch.Tensor(my_y)

    dataset = TensorDataset(tensor_x,tensor_y)
    
    return dataset

# %%
def data_test(path, filenames):
    my_x = []    
    my_y_np = np.array([])
    
    
    for filename in filenames:
        
        my_x.append(cv2.imread(os.path.join(path, filename), 0))
        my_y_np= np.append(my_y_np, np.array(-1).astype(np.uint8))
        
    my_y = torch.from_numpy(my_y_np).float()
    
    tensor_x = torch.Tensor(my_x)
    tensor_x = tensor_x.unsqueeze(1)
    tensor_y = torch.Tensor(my_y)
    
    dataset = TensorDataset(tensor_x,tensor_y)
    return dataset

# %%
def train(network, epochs, dataloader_train, dataloader_val, opt, scheduler, early_stopping):
    
    all_train_losses = []
    all_valid_losses = []
    
    criterion = nn.CrossEntropyLoss()


    
    for epoch in range(epochs):
        train_loss = 0
        train_acc = 0
        train_n = 0
        
        val_loss = 0
        val_acc = 0
        val_n = 0
        
        network.train()
        for i, (X,y) in enumerate(dataloader_train):
            X, y = X.cuda(), y.cuda()
            output = network(X)
            loss = criterion(output, y.long())
            opt.zero_grad()
            loss.backward()
            opt.step()

            train_loss += loss.item() * y.size(0)
            train_acc += (output.max(1)[1] == y).sum().item()
            train_n += y.size(0)
        
        train_loss = train_loss / train_n
        all_train_losses.append(train_loss)

        network.eval()
        for i, (X,y) in enumerate(dataloader_val):
            X, y = X.cuda(), y.cuda()        
            output = network(X)
            loss = criterion(output, y.long())
            val_loss += loss.item() * y.size(0)
            val_acc += (output.max(1)[1] == y).sum().item()
            val_n += y.size(0)
            
        val_loss = val_loss/val_n
        all_valid_losses.append(val_loss)

        early_stopping(val_loss, network)

        if early_stopping.early_stop:
            print("Early stopping")
            break
        
        scheduler.step()
        
        print('epoch:{}, \t lr:{}, \n train loss:{}, \t val loss:{}, \n train acc:{}, \t\t\t val acc:{} \n\n'.format(epoch, scheduler.get_last_lr() , train_loss, val_loss, train_acc/train_n, val_acc/val_n))
    
        
        
    # load the last checkpoint with the best model
    network.load_state_dict(torch.load('checkpoint.pt'))

    return  network, all_train_losses, all_valid_losses

# %%
def evaluate(network, dataloader):
    network.eval()
    
    total_loss = 0
    total_acc = 0
    n = 0
    
    criterion = nn.CrossEntropyLoss()
    
    for i, (X,y) in enumerate(dataloader):
        X, y = X.cuda(), y.cuda()
        output = network(X)
        loss = F.cross_entropy(output, y.long())
        
        total_loss += loss.item() * y.size(0)
        total_acc += (output.max(1)[1] == y).sum().item()
        n += y.size(0)

    print('Validation Loss: {}, Acc:{}'.format(total_loss/n, total_acc/n))

# %%
def predict(network, dataloader):
    network.eval()
    
    n = 0
    
    preds = []
    
    for i, (X,y) in enumerate(dataloader):
        X = X.cuda()
        output = network(X)
        preds.append(output.max(1)[1].item())

    return preds

# %%
path_train = os.path.join(os.getcwd(), "ch01-train")
filenames_train = os.listdir(path_train)

path_test = os.path.join(os.getcwd(), "ch01-test")
filenames_test = os.listdir(path_test)

# %%
dataset_train = data_train(path_train, filenames_train)

# %%
dataset_test = data_test(path_test, filenames_test)

# %%
train_set, val_set = torch.utils.data.random_split(dataset_train, [50000, 10000])

dataloader_train = DataLoader(train_set, batch_size = 128) 
dataloader_val = DataLoader(val_set, batch_size = 128) 
dataloader_test = DataLoader(dataset_test, batch_size = 1)

# %%
network = Network().cuda()
network.train()
epochs = 60
    
opt = torch.optim.Adam(network.parameters(), lr=0.001)
scheduler = StepLR(opt, step_size=5, gamma=0.6)
early_stopping = EarlyStopping(patience=15, verbose=True)
    
network, all_train_losses, all_valid_losses = train(network, epochs, dataloader_train, dataloader_val, opt, scheduler, early_stopping)
# Out:
# Validation loss decreased (inf --> 0.085337).  Saving model ...
# epoch:0, 	 lr:[0.001],
#  train loss:0.25623795285344125, 	 val loss:0.08533694754838944,
#  train acc:0.91666, 			 val acc:0.9748
#
#
# Validation loss decreased (0.085337 --> 0.046004).  Saving model ...
# epoch:1, 	 lr:[0.001],
#  train loss:0.06871950185835361, 	 val loss:0.046003559476137164,
#  train acc:0.97894, 			 val acc:0.9863
#
#
# EarlyStopping counter: 1 out of 15
# epoch:2, 	 lr:[0.001],
#  train loss:0.05416755557663739, 	 val loss:0.055090260660648344,
#  train acc:0.98348, 			 val acc:0.9853
#
#
# Validation loss decreased (0.046004 --> 0.033974).  Saving model ...
# epoch:3, 	 lr:[0.001],
#  train loss:0.04601957254856825, 	 val loss:0.033973702901601795,
#  train acc:0.98552, 			 val acc:0.9891
#
#
# Validation loss decreased (0.033974 --> 0.027575).  Saving model ...
# epoch:4, 	 lr:[0.0006],
#  train loss:0.04205984490545467, 	 val loss:0.02757466192469001,
#  train acc:0.98644, 			 val acc:0.9918
#
#
# Validation loss decreased (0.027575 --> 0.023950).  Saving model ...
# epoch:5, 	 lr:[0.0006],
#  train loss:0.02984451018564403, 	 val loss:0.02395028488012031,
#  train acc:0.9902, 			 val acc:0.9927
#
#
# EarlyStopping counter: 1 out of 15
# epoch:6, 	 lr:[0.0006],
#  train loss:0.026384672488048672, 	 val loss:0.02524903707280755,
#  train acc:0.99176, 			 val acc:0.9925
#
#
# EarlyStopping counter: 2 out of 15
# epoch:7, 	 lr:[0.0006],
#  train loss:0.024937652568407357, 	 val loss:0.028303434740006923,
#  train acc:0.99188, 			 val acc:0.9914
#
#
# Validation loss decreased (0.023950 --> 0.021473).  Saving model ...
# epoch:8, 	 lr:[0.0006],
#  train loss:0.0239255635715276, 	 val loss:0.021472881010174753,
#  train acc:0.99256, 			 val acc:0.9936
#
#
# EarlyStopping counter: 1 out of 15
# epoch:9, 	 lr:[0.00035999999999999997],
#  train loss:0.02068709792226553, 	 val loss:0.022892121295072138,
#  train acc:0.9931, 			 val acc:0.9931
#
#
# EarlyStopping counter: 2 out of 15
# epoch:10, 	 lr:[0.00035999999999999997],
#  train loss:0.016504919569417836, 	 val loss:0.02254759815260768,
#  train acc:0.995, 			 val acc:0.9931
#
#
# EarlyStopping counter: 3 out of 15
# epoch:11, 	 lr:[0.00035999999999999997],
#  train loss:0.01570101504516788, 	 val loss:0.02312701104581356,
#  train acc:0.9948, 			 val acc:0.9932
#
#
# EarlyStopping counter: 4 out of 15
# epoch:12, 	 lr:[0.00035999999999999997],
#  train loss:0.015152068384364246, 	 val loss:0.027486227324604987,
#  train acc:0.9951, 			 val acc:0.9927
#
#
# EarlyStopping counter: 5 out of 15
# epoch:13, 	 lr:[0.00035999999999999997],
#  train loss:0.01339873719714582, 	 val loss:0.02418640185710974,
#  train acc:0.99548, 			 val acc:0.9939
#
#
# EarlyStopping counter: 6 out of 15
# epoch:14, 	 lr:[0.00021599999999999996],
#  train loss:0.014611233769841492, 	 val loss:0.02316747914608568,
#  train acc:0.99524, 			 val acc:0.9941
#
#
# EarlyStopping counter: 7 out of 15
# epoch:15, 	 lr:[0.00021599999999999996],
#  train loss:0.010706218008736614, 	 val loss:0.022511766505334527,
#  train acc:0.99648, 			 val acc:0.9947
#
#
# EarlyStopping counter: 8 out of 15
# epoch:16, 	 lr:[0.00021599999999999996],
#  train loss:0.010919452821074519, 	 val loss:0.021918983779568225,
#  train acc:0.9962, 			 val acc:0.995
#
#
# EarlyStopping counter: 9 out of 15
# epoch:17, 	 lr:[0.00021599999999999996],
#  train loss:0.009521841740515083, 	 val loss:0.02167698528857436,
#  train acc:0.9967, 			 val acc:0.995
#
#
# EarlyStopping counter: 10 out of 15
# epoch:18, 	 lr:[0.00021599999999999996],
#  train loss:0.00916540604093927, 	 val loss:0.021860336537915283,
#  train acc:0.9971, 			 val acc:0.9944
#
#
# EarlyStopping counter: 11 out of 15
# epoch:19, 	 lr:[0.00012959999999999998],
#  train loss:0.009214776183888317, 	 val loss:0.023674217304494233,
#  train acc:0.99678, 			 val acc:0.9943
#
#
# Validation loss decreased (0.021473 --> 0.020929).  Saving model ...
# epoch:20, 	 lr:[0.00012959999999999998],
#  train loss:0.00736679778737016, 	 val loss:0.020928895910410212,
#  train acc:0.99746, 			 val acc:0.9952
#
#
# EarlyStopping counter: 1 out of 15
# epoch:21, 	 lr:[0.00012959999999999998],
#  train loss:0.007912677900483832, 	 val loss:0.021207453348627316,
#  train acc:0.99726, 			 val acc:0.9947
#
#
# Validation loss decreased (0.020929 --> 0.020712).  Saving model ...
# epoch:22, 	 lr:[0.00012959999999999998],
#  train loss:0.0066207259369839445, 	 val loss:0.020711835134611466,
#  train acc:0.99816, 			 val acc:0.9947
#
#
# EarlyStopping counter: 1 out of 15
# epoch:23, 	 lr:[0.00012959999999999998],
#  train loss:0.006807646378448116, 	 val loss:0.02162903377187904,
#  train acc:0.9977, 			 val acc:0.9948
#
#
# EarlyStopping counter: 2 out of 15
# epoch:24, 	 lr:[7.775999999999999e-05],
#  train loss:0.006978070133412257, 	 val loss:0.02173576403843472,
#  train acc:0.99768, 			 val acc:0.9944
#
#
# EarlyStopping counter: 3 out of 15
# epoch:25, 	 lr:[7.775999999999999e-05],
#  train loss:0.00557406072378857, 	 val loss:0.02325260325317504,
#  train acc:0.99816, 			 val acc:0.9944
#
#
# EarlyStopping counter: 4 out of 15
# epoch:26, 	 lr:[7.775999999999999e-05],
#  train loss:0.005460092867268249, 	 val loss:0.021484568999073236,
#  train acc:0.99808, 			 val acc:0.9952
#
#
# EarlyStopping counter: 5 out of 15
# epoch:27, 	 lr:[7.775999999999999e-05],
#  train loss:0.0056159247301612045, 	 val loss:0.020809722750080983,
#  train acc:0.99816, 			 val acc:0.9952
#
#
# EarlyStopping counter: 6 out of 15
# epoch:28, 	 lr:[7.775999999999999e-05],
#  train loss:0.005398088838467374, 	 val loss:0.021337636184532313,
#  train acc:0.99812, 			 val acc:0.9954
#
#
# EarlyStopping counter: 7 out of 15
# epoch:29, 	 lr:[4.665599999999999e-05],
#  train loss:0.005609752715919167, 	 val loss:0.021668590805970597,
#  train acc:0.99806, 			 val acc:0.9952
#
#
# EarlyStopping counter: 8 out of 15
# epoch:30, 	 lr:[4.665599999999999e-05],
#  train loss:0.004506042335988022, 	 val loss:0.021851389926526462,
#  train acc:0.99836, 			 val acc:0.9949
#
#
# EarlyStopping counter: 9 out of 15
# epoch:31, 	 lr:[4.665599999999999e-05],
#  train loss:0.0048290815137932075, 	 val loss:0.02231464500829461,
#  train acc:0.99826, 			 val acc:0.9951
#
#
# EarlyStopping counter: 10 out of 15
# epoch:32, 	 lr:[4.665599999999999e-05],
#  train loss:0.004906575217391946, 	 val loss:0.022725324451044436,
#  train acc:0.99834, 			 val acc:0.9947
#
#
# EarlyStopping counter: 11 out of 15
# epoch:33, 	 lr:[4.665599999999999e-05],
#  train loss:0.004652193863005377, 	 val loss:0.021832245391301696,
#  train acc:0.99842, 			 val acc:0.9948
#
#
# EarlyStopping counter: 12 out of 15
# epoch:34, 	 lr:[2.7993599999999992e-05],
#  train loss:0.004152100413553417, 	 val loss:0.021637175569526153,
#  train acc:0.99854, 			 val acc:0.995
#
#
# EarlyStopping counter: 13 out of 15
# epoch:35, 	 lr:[2.7993599999999992e-05],
#  train loss:0.004346544860422436, 	 val loss:0.022074405055839453,
#  train acc:0.99858, 			 val acc:0.9951
#
#
# EarlyStopping counter: 14 out of 15
# epoch:36, 	 lr:[2.7993599999999992e-05],
#  train loss:0.003706696906266734, 	 val loss:0.022118744611612055,
#  train acc:0.99892, 			 val acc:0.9947
#
#
# EarlyStopping counter: 15 out of 15
# Early stopping

# %%
fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(all_train_losses)+1),all_train_losses, label='Training Loss')
plt.plot(range(1,len(all_valid_losses)+1),all_valid_losses,label='Validation Loss')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.ylim(0, 0.2) # consistent scale
plt.xlim(1, len(all_train_losses)) # consistent scale
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
preds = predict(network, dataloader_test)

# %%
pd.Series(preds, index = filenames_test).to_csv("test_predictions_2.csv", header = None)
# Out:
# c:\users\m\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
