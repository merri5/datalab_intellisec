# %%
import torch
import torch.nn as nn
from torch.functional import F
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import Dataset, TensorDataset, DataLoader

from pytorchtools import EarlyStopping

import pandas as pd
import numpy as np
import cv2
import os

from matplotlib import pyplot as plt
from sklearn.metrics import f1_score

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size(0), -1)
    
def Network():
    network = nn.Sequential(
        nn.Conv2d(1, 16, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.Conv2d(16, 16, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        
    
        
        nn.Conv2d(16, 16, 4, stride=2, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        
        nn.Dropout(0.4),
        
        
        
        nn.Conv2d(16, 32, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        
        nn.Conv2d(32, 32, 3, stride=1, padding=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        
        nn.Conv2d(32, 32, 4, stride=2, padding=1),
        nn.ReLU(),
        
        nn.Dropout(0.4),
        
        
        
        
        nn.Conv2d(32, 64, 4, stride=1, padding=1),
        nn.ReLU(),
        nn.Dropout(0.4),
        
        Flatten(),
        nn.Linear(64*6*6,100),
        nn.ReLU(),
        nn.Linear(100, 10)
    )
    return network

# %%
def data_train(path, filenames):
    my_x = []
    my_y_np = np.array([])
    
    for filename in filenames:
        my_x.append(cv2.imread(os.path.join(path, filename), 0))
        pre, ext = os.path.splitext(os.path.join(path, filename))
        my_y_np = np.append(my_y_np, np.array(ext[1:]).astype(np.uint8))
        
    my_y = torch.from_numpy(my_y_np).float()
    
    tensor_x = torch.Tensor(my_x)
    tensor_x = tensor_x.unsqueeze(1)
    tensor_y = torch.Tensor(my_y)

    dataset = TensorDataset(tensor_x,tensor_y)
    
    return dataset

# %%
def data_test(path, filenames):
    my_x = []    
    my_y_np = np.array([])
    
    
    for filename in filenames:
        
        my_x.append(cv2.imread(os.path.join(path, filename), 0))
        my_y_np= np.append(my_y_np, np.array(-1).astype(np.uint8))
        
    my_y = torch.from_numpy(my_y_np).float()
    
    tensor_x = torch.Tensor(my_x)
    tensor_x = tensor_x.unsqueeze(1)
    tensor_y = torch.Tensor(my_y)
    
    dataset = TensorDataset(tensor_x,tensor_y)
    return dataset

# %%
def train(network, epochs, dataloader_train, dataloader_val, opt, scheduler, early_stopping):
    
    all_train_losses = []
    all_valid_losses = []
    
    criterion = nn.CrossEntropyLoss()


    for epoch in range(epochs):
        train_loss = 0
        train_acc = 0
        train_n = 0
        
        val_loss = 0
        val_acc = 0
        val_n = 0
        
        network.train()
        for i, (X,y) in enumerate(dataloader_train):
            X, y = X.cuda(), y.cuda()
            output = network(X)
            loss = criterion(output, y.long())
            opt.zero_grad()
            loss.backward()
            opt.step()

            train_loss += loss.item() * y.size(0)
            train_acc += (output.max(1)[1] == y).sum().item()
            train_n += y.size(0)
        
        train_loss = train_loss / train_n
        all_train_losses.append(train_loss)

        network.eval()
        for i, (X,y) in enumerate(dataloader_val):
            X, y = X.cuda(), y.cuda()        
            output = network(X)
            loss = criterion(output, y.long())
            val_loss += loss.item() * y.size(0)
            val_acc += (output.max(1)[1] == y).sum().item()
            val_n += y.size(0)
            
        val_loss = val_loss/val_n
        all_valid_losses.append(val_loss)

        early_stopping(val_loss, network)

        if early_stopping.early_stop:
            print("Early stopping")
            break
        
        scheduler.step()
        
        print('epoch:{}, \t lr:{}, \n train loss:{}, \t val loss:{}, \n train acc:{}, \t\t\t val acc:{} \n\n'.format(epoch, scheduler.get_last_lr() , train_loss, val_loss, train_acc/train_n, val_acc/val_n))
    
        
        
    # load the last checkpoint with the best model
    network.load_state_dict(torch.load('checkpoint.pt'))

    return  network, all_train_losses, all_valid_losses

# %%
def evaluate(network, dataloader):
    network.eval()
    
    total_loss = 0
    total_acc = 0
    n = 0
    
    criterion = nn.CrossEntropyLoss()
    
    for i, (X,y) in enumerate(dataloader):
        X, y = X.cuda(), y.cuda()
        output = network(X)
        loss = F.cross_entropy(output, y.long())
        
        total_loss += loss.item() * y.size(0)
        total_acc += (output.max(1)[1] == y).sum().item()
        n += y.size(0)

    print('Validation Loss: {}, Acc:{}'.format(total_loss/n, total_acc/n))

# %%
def predict(network, dataloader):
    network.eval()
    
    n = 0
    
    preds = []
    
    for i, (X,y) in enumerate(dataloader):
        X = X.cuda()
        output = network(X)
        preds.append(output.max(1)[1].item())

    return preds

# %%
path_train = os.path.join(os.getcwd(), "ch01-train")
filenames_train = os.listdir(path_train)

path_test = os.path.join(os.getcwd(), "ch01-test")
filenames_test = os.listdir(path_test)

# %%
dataset_train = data_train(path_train, filenames_train)

# %%
dataset_test = data_test(path_test, filenames_test)

# %%
train_set, val_set = torch.utils.data.random_split(dataset_train, [50000, 10000])

dataloader_train = DataLoader(train_set, batch_size = 128) 
dataloader_val = DataLoader(val_set, batch_size = 128) 
dataloader_test = DataLoader(dataset_test, batch_size = 1)

# %%
network = Network().cuda()
network.train()
epochs = 60
    
opt = torch.optim.Adam(network.parameters(), lr=0.001)
scheduler = StepLR(opt, step_size=5, gamma=0.6)
early_stopping = EarlyStopping(patience=15, verbose=True)
    
network, all_train_losses, all_valid_losses = train(network, epochs, dataloader_train, dataloader_val, opt, scheduler, early_stopping)
# Out:
# Validation loss decreased (inf --> 0.075720).  Saving model ...
# epoch:0, 	 lr:[0.001],
#  train loss:0.2572487684416771, 	 val loss:0.07571978442668915,
#  train acc:0.91556, 			 val acc:0.9748
#
#
# Validation loss decreased (0.075720 --> 0.037385).  Saving model ...
# epoch:1, 	 lr:[0.001],
#  train loss:0.0759956451177597, 	 val loss:0.03738516982793808,
#  train acc:0.97616, 			 val acc:0.9886
#
#
# Validation loss decreased (0.037385 --> 0.033727).  Saving model ...
# epoch:2, 	 lr:[0.001],
#  train loss:0.058845844653844834, 	 val loss:0.033726767069101334,
#  train acc:0.9805, 			 val acc:0.9874
#
#
# Validation loss decreased (0.033727 --> 0.029614).  Saving model ...
# epoch:3, 	 lr:[0.001],
#  train loss:0.04960177429497242, 	 val loss:0.029613836777210235,
#  train acc:0.98432, 			 val acc:0.9895
#
#
# Validation loss decreased (0.029614 --> 0.025349).  Saving model ...
# epoch:4, 	 lr:[0.0006],
#  train loss:0.044724940852820874, 	 val loss:0.025349180781841278,
#  train acc:0.98624, 			 val acc:0.9913
#
#
# Validation loss decreased (0.025349 --> 0.020230).  Saving model ...
# epoch:5, 	 lr:[0.0006],
#  train loss:0.03357737758606672, 	 val loss:0.02022978776693344,
#  train acc:0.9896, 			 val acc:0.9942
#
#
# Validation loss decreased (0.020230 --> 0.019486).  Saving model ...
# epoch:6, 	 lr:[0.0006],
#  train loss:0.030056695534735917, 	 val loss:0.019486412496119737,
#  train acc:0.99066, 			 val acc:0.993
#
#
# Validation loss decreased (0.019486 --> 0.019483).  Saving model ...
# epoch:7, 	 lr:[0.0006],
#  train loss:0.03010929542526603, 	 val loss:0.019482641575485467,
#  train acc:0.99028, 			 val acc:0.9932
#
#
# Validation loss decreased (0.019483 --> 0.017988).  Saving model ...
# epoch:8, 	 lr:[0.0006],
#  train loss:0.027450494246035816, 	 val loss:0.017988316221535208,
#  train acc:0.99164, 			 val acc:0.9941
#
#
# EarlyStopping counter: 1 out of 15
# epoch:9, 	 lr:[0.00035999999999999997],
#  train loss:0.026455598488152026, 	 val loss:0.018497346233949066,
#  train acc:0.9915, 			 val acc:0.9945
#
#
# Validation loss decreased (0.017988 --> 0.016901).  Saving model ...
# epoch:10, 	 lr:[0.00035999999999999997],
#  train loss:0.017572001131027935, 	 val loss:0.016901494145952167,
#  train acc:0.99434, 			 val acc:0.9948
#
#
# Validation loss decreased (0.016901 --> 0.016796).  Saving model ...
# epoch:11, 	 lr:[0.00035999999999999997],
#  train loss:0.017343061655312776, 	 val loss:0.01679629234112799,
#  train acc:0.9946, 			 val acc:0.9951
#
#
# EarlyStopping counter: 1 out of 15
# epoch:12, 	 lr:[0.00035999999999999997],
#  train loss:0.01687773578118533, 	 val loss:0.01833764975145459,
#  train acc:0.99482, 			 val acc:0.995
#
#
# EarlyStopping counter: 2 out of 15
# epoch:13, 	 lr:[0.00035999999999999997],
#  train loss:0.016579907407835125, 	 val loss:0.01713029944896698,
#  train acc:0.99472, 			 val acc:0.9944
#
#
# EarlyStopping counter: 3 out of 15
# epoch:14, 	 lr:[0.00021599999999999996],
#  train loss:0.0163178318811208, 	 val loss:0.019247272889316082,
#  train acc:0.99442, 			 val acc:0.9946
#
#
# EarlyStopping counter: 4 out of 15
# epoch:15, 	 lr:[0.00021599999999999996],
#  train loss:0.013475172725990414, 	 val loss:0.01821371944770217,
#  train acc:0.9952, 			 val acc:0.9951
#
#
# EarlyStopping counter: 5 out of 15
# epoch:16, 	 lr:[0.00021599999999999996],
#  train loss:0.011995812285095454, 	 val loss:0.01758732532709837,
#  train acc:0.9961, 			 val acc:0.9951
#
#
# Validation loss decreased (0.016796 --> 0.016494).  Saving model ...
# epoch:17, 	 lr:[0.00021599999999999996],
#  train loss:0.010419440130069851, 	 val loss:0.016494461389631034,
#  train acc:0.99654, 			 val acc:0.995
#
#
# EarlyStopping counter: 1 out of 15
# epoch:18, 	 lr:[0.00021599999999999996],
#  train loss:0.011392674928568304, 	 val loss:0.017378959616459907,
#  train acc:0.99636, 			 val acc:0.9954
#
#
# EarlyStopping counter: 2 out of 15
# epoch:19, 	 lr:[0.00012959999999999998],
#  train loss:0.011304153818693012, 	 val loss:0.017285287997499107,
#  train acc:0.99616, 			 val acc:0.9946
#
#
# Validation loss decreased (0.016494 --> 0.015769).  Saving model ...
# epoch:20, 	 lr:[0.00012959999999999998],
#  train loss:0.009459761529192328, 	 val loss:0.015768948866985738,
#  train acc:0.99682, 			 val acc:0.9957
#
#
# EarlyStopping counter: 1 out of 15
# epoch:21, 	 lr:[0.00012959999999999998],
#  train loss:0.0089689444305934, 	 val loss:0.01606989859882742,
#  train acc:0.99686, 			 val acc:0.9956
#
#
# EarlyStopping counter: 2 out of 15
# epoch:22, 	 lr:[0.00012959999999999998],
#  train loss:0.008792085912004113, 	 val loss:0.01619214735319838,
#  train acc:0.9971, 			 val acc:0.996
#
#
# Validation loss decreased (0.015769 --> 0.015528).  Saving model ...
# epoch:23, 	 lr:[0.00012959999999999998],
#  train loss:0.008629603801760822, 	 val loss:0.015527597063593567,
#  train acc:0.99716, 			 val acc:0.9959
#
#
# Validation loss decreased (0.015528 --> 0.014965).  Saving model ...
# epoch:24, 	 lr:[7.775999999999999e-05],
#  train loss:0.00773045823380351, 	 val loss:0.014964624936133623,
#  train acc:0.99714, 			 val acc:0.9961
#
#
# EarlyStopping counter: 1 out of 15
# epoch:25, 	 lr:[7.775999999999999e-05],
#  train loss:0.00756737136349082, 	 val loss:0.015890583795215935,
#  train acc:0.99746, 			 val acc:0.9958
#
#
# EarlyStopping counter: 2 out of 15
# epoch:26, 	 lr:[7.775999999999999e-05],
#  train loss:0.007306717592999339, 	 val loss:0.015449941776786,
#  train acc:0.99742, 			 val acc:0.9961
#
#
# EarlyStopping counter: 3 out of 15
# epoch:27, 	 lr:[7.775999999999999e-05],
#  train loss:0.0067914646753109995, 	 val loss:0.01632454139571637,
#  train acc:0.99782, 			 val acc:0.9956
#
#
# EarlyStopping counter: 4 out of 15
# epoch:28, 	 lr:[7.775999999999999e-05],
#  train loss:0.006252059979755431, 	 val loss:0.01564103686157614,
#  train acc:0.99776, 			 val acc:0.9956
#
#
# EarlyStopping counter: 5 out of 15
# epoch:29, 	 lr:[4.665599999999999e-05],
#  train loss:0.006389347496237606, 	 val loss:0.016515013074316083,
#  train acc:0.99808, 			 val acc:0.9959
#
#
# EarlyStopping counter: 6 out of 15
# epoch:30, 	 lr:[4.665599999999999e-05],
#  train loss:0.006593463110574521, 	 val loss:0.0161855766126886,
#  train acc:0.9977, 			 val acc:0.996
#
#
# EarlyStopping counter: 7 out of 15
# epoch:31, 	 lr:[4.665599999999999e-05],
#  train loss:0.006615293320976197, 	 val loss:0.01617124247327447,
#  train acc:0.99768, 			 val acc:0.996
#
#
# EarlyStopping counter: 8 out of 15
# epoch:32, 	 lr:[4.665599999999999e-05],
#  train loss:0.005515740264840424, 	 val loss:0.015532281425688415,
#  train acc:0.99818, 			 val acc:0.9962
#
#
# EarlyStopping counter: 9 out of 15
# epoch:33, 	 lr:[4.665599999999999e-05],
#  train loss:0.005836857914971187, 	 val loss:0.01624605574440211,
#  train acc:0.99774, 			 val acc:0.9964
#
#
# EarlyStopping counter: 10 out of 15
# epoch:34, 	 lr:[2.7993599999999992e-05],
#  train loss:0.005236638692477718, 	 val loss:0.016681956166401505,
#  train acc:0.9981, 			 val acc:0.9962
#
#
# EarlyStopping counter: 11 out of 15
# epoch:35, 	 lr:[2.7993599999999992e-05],
#  train loss:0.005624670171691105, 	 val loss:0.016457432031724603,
#  train acc:0.99816, 			 val acc:0.9965
#
#
# EarlyStopping counter: 12 out of 15
# epoch:36, 	 lr:[2.7993599999999992e-05],
#  train loss:0.005126573578387033, 	 val loss:0.01596015825467184,
#  train acc:0.99842, 			 val acc:0.9965
#
#
# EarlyStopping counter: 13 out of 15
# epoch:37, 	 lr:[2.7993599999999992e-05],
#  train loss:0.005162690393216908, 	 val loss:0.016128018734697252,
#  train acc:0.99832, 			 val acc:0.9965
#
#
# EarlyStopping counter: 14 out of 15
# epoch:38, 	 lr:[2.7993599999999992e-05],
#  train loss:0.006127910068128258, 	 val loss:0.016087732581980527,
#  train acc:0.99782, 			 val acc:0.9961
#
#
# EarlyStopping counter: 15 out of 15
# Early stopping

# %%
fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(all_train_losses)+1),all_train_losses, label='Training Loss')
plt.plot(range(1,len(all_valid_losses)+1),all_valid_losses,label='Validation Loss')


plt.xlabel('epochs')
plt.ylabel('loss')
plt.ylim(0, 0.2) # consistent scale
plt.xlim(1, len(all_train_losses)) # consistent scale
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
preds = predict(network, dataloader_test)

# %%
pd.Series(preds, index = filenames_test).to_csv("test_predictions_1.csv", header = None)
# Out:
# c:\users\m\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
